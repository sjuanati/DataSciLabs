# %% [markdown]
# # Logistic Regression Project

# %% [markdown]
# The advertising data set will indicate whether or not a particular internet user clicked on an Advertisement. We will try to create a model that will predict whether or not they will click on an ad based off the features of that user.
#
# This data set contains the following features:
#
# * 'Daily Time Spent on Site': consumer time on site in minutes
# * 'Age': cutomer age in years
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline of the advertisement
# * 'City': City of consumer
# * 'Male': Whether or not consumer was male
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

# %% [markdown]
# ## Data retrieval

# %%
ad_data = pd.read_csv('./filez/advertising.csv')
ad_data.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
#
#                         Ad Topic Line         City  Male     Country  \
# 0  Cloned 5thgeneration orchestration  Wrightburgh     0     Tunisia
# 1  Monitored national standardization    West Jodi     1       Nauru
# 2    Organic bottom-line service-desk     Davidton     0  San Marino
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0

# %%
# DataFrame info
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
# statistical info
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# show `Daily Time Spent on Site` by `age`
sns.displot(data=ad_data, x='Age', bins=30, kde=True)

# %%
# show relationship between Area Income versus Age in jointplot chart
sns.jointplot(data=ad_data, x='Age', y='Area Income')

# %%
# show kde distributions of `Daily Time Spent on Site` vs. `Age` in jointplot chart
sns.jointplot(data=ad_data, x="Age", y="Daily Time Spent on Site", kind="kde", fill=True, color='red')

# %%
# show `Daily Time Spent on Site` vs. `Daily Internet Usage` in jointplot chart
# -> two clusters here:
# 1) higher in usage and time spent
# 2) lower in usage and time spent
sns.jointplot(data=ad_data, x='Daily Time Spent on Site', y='Daily Internet Usage')

# %%
# show pairplot for `Click on Ad` feature
# -> clear relationships with age, time spent on site, income..
sns.pairplot(data=ad_data, hue='Clicked on Ad')

# %% [markdown]
# ## Logistic Regression

# %%
# remove str features for now (even they may influence)
ad_data.drop(['Ad Topic Line', 'City', 'Country','Timestamp'], axis=1, inplace=True)
ad_data.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                     68.95   35     61833.90                256.09     0
# 1                     80.23   31     68441.85                193.77     1
# 2                     69.47   26     59785.94                236.50     0
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0

# %%
# split data for model
from sklearn.model_selection import train_test_split

X = ad_data.drop("Clicked on Ad", axis=1)
y = ad_data["Clicked on Ad"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=101
)

# %%
# train model
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=1000)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## Evaluate the Model

# %%
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       157
#            1       0.94      0.90      0.92       143
#
#     accuracy                           0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300
#
# [[149   8]
#  [ 14 129]]

# %%
# Random prediction
new_data = pd.DataFrame({
    'Daily Time Spent on Site': [50],
    'Age': [46],
    'Area Income': [75000],
    'Daily Internet Usage': [250],
    'Male': [1]
})

new_prediction = logmodel.predict(new_data)
print(f"Click prediction: {'yes' if new_prediction[0] else 'no'}")
# Out:
# Click prediction: yes
