# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# TODO: def

# %% [markdown]
# ### Importing the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

sns.set_style("whitegrid")

# %%
dataset = pd.read_csv('./filez/Social_Network_Ads.csv')
dataset.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %% [markdown]
# ### EDA

# %%
sns.scatterplot(
    dataset,
    x="Age",
    y="EstimatedSalary",
    hue="Purchased",
    palette={0: "red", 1: "green"},
)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# ### Splitting the dataset into the Train/Test set

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop("Purchased", axis=1)
y = dataset["Purchased"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Function for visualizing Test set results

# %%
def show_test_scatter(kernel_type: str, classifier):
    # Reverse the scaling of the test set
    X_test_inv = sc.inverse_transform(X_test)

    # Convert the scaled test set back to a DataFrame
    X_test_inv_df = pd.DataFrame(X_test_inv, columns=["Age", "EstimatedSalary"])

    # Add the predictions to this DataFrame
    y_pred = classifier.predict(X_test)
    X_test_inv_df["Purchased"] = y_pred

    # Show the scatter plot
    sns.scatterplot(
        data=X_test_inv_df,
        x="Age",
        y="EstimatedSalary",
        hue="Purchased",
        palette={0: "red", 1: "green"},
    )
    title = (
        "SVM - Linear Kernel" if kernel_type == "linear" else "SVM - Gaussian Kernel"
    )
    plt.title(f"{title} (Testing set)")
    plt.show()

# %% [markdown]
# ### Function for visualizing Test set results including decision boundary

# %%
# shows decision boundary
def show_train_scatter_boundary(kernel_type: str, classifier):
    X_set, y_set = sc.inverse_transform(X_test), y_test
    X1, X2 = np.meshgrid(
        np.arange(start=X_set[:, 0].min() - 10, stop=X_set[:, 0].max() + 10, step=0.25),
        np.arange(
            start=X_set[:, 1].min() - 1000, stop=X_set[:, 1].max() + 1000, step=0.25
        ),
    )

    # Prepare mesh grid as DataFrame for transformation
    mesh_df = pd.DataFrame(
        np.c_[X1.ravel(), X2.ravel()], columns=["Age", "EstimatedSalary"]
    )

    # Predict using the transformed mesh grid
    Z = classifier.predict(sc.transform(mesh_df)).reshape(X1.shape)

    # Plot the decision regions
    plt.contourf(X1, X2, Z, alpha=0.75, cmap=ListedColormap(("red", "green")))

    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())

    # Define colors for each class
    colors = ["red", "green"]

    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(
            X_set[y_set == j, 0], X_set[y_set == j, 1], color=colors[i], label=j
        )

    title = (
        "SVM - Linear Kernel" if kernel_type == "linear" else "SVM - Gaussian Kernel"
    )

    plt.title(f"{title} (Training set)")
    plt.xlabel("Age")
    plt.ylabel("Estimated Salary")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Function for Evaluating the SVM model with Linear Kernel

# %%
def evaluate_model(classifier):
    y_pred = classifier.predict(X_test)

    print(f"1) classification_report:\n\n", classification_report(y_test, y_pred))
    print(f"2) confusion_matrix:\n\n", confusion_matrix(y_test, y_pred), "\n")
    print(f"3) accuracy_score:\n\n", accuracy_score(y_test, y_pred))

# %% [markdown]
# # SVM model with Linear Kernel

# %% [markdown]
# ### Training the SVM model with Linear Kernel on the Training set

# %%
from sklearn.svm import SVC

classifier = SVC(kernel="linear", random_state=0)
classifier.fit(X_train, y_train)
classifier.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 0,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# ### Predicting a new result

# %%
def make_prediction(age: int, salary: int):
    new_data = pd.DataFrame([[age, salary]], columns=['Age', 'EstimatedSalary'])
    new_pred = classifier.predict(sc.transform(new_data))
    print(f"new prediction for age: {age} & salary: ${salary:,} -> {new_pred[0]}")

make_prediction(19, 19000)
make_prediction(32, 150000)
# Out:
# new prediction for age: 19 & salary: $19,000 -> 0
# new prediction for age: 32 & salary: $150,000 -> 1

# %% [markdown]
# ### Visualising the Test set results with Linear SVM model

# %%
show_test_scatter('linear', classifier)

# %%
show_train_scatter_boundary('linear', classifier)

# %% [markdown]
# ### Evaluating the SVM model with Linear Kernel

# %%
evaluate_model(classifier)
# Out:
# 1) classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        68
#            1       0.92      0.75      0.83        32
#
#     accuracy                           0.90       100
#    macro avg       0.91      0.86      0.88       100
# weighted avg       0.90      0.90      0.90       100
#
# 2) confusion_matrix:
#
#  [[66  2]
#  [ 8 24]]
#
# 3) accuracy_score:
#
#  0.9

# %% [markdown]
# # SVM model with Gaussian Kernel

# %% [markdown]
# ### Training the SVM model with Gaussian Kernel on the Training set

# %%
from sklearn.svm import SVC

classifier = SVC(kernel='rbf', random_state=0)
classifier.fit(X_train, y_train)
classifier.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 0,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# ### Visualising the Test set results with with Gaussian SVM model

# %%
show_test_scatter('gaussian', classifier)

# %%
show_train_scatter_boundary('gaussian', classifier)

# %% [markdown]
# ### Evaluating the SVM model with Gaussian Kernel

# %%
evaluate_model(classifier)
# Out:
# 1) classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        68
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.93       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.93      0.93      0.93       100
#
# 2) confusion_matrix:
#
#  [[64  4]
#  [ 3 29]]
#
# 3) accuracy_score:
#
#  0.93
